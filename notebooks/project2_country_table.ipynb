# %%
import pandas as pd

path = r"C:\Users\ShannonKnight\OneDrive - PPO Serve\Documents\ironhack\Week 4\project_2\data\raw data\New_data_2019.csv"

path3 = r"C:\Users\ShannonKnight\OneDrive - PPO Serve\Documents\ironhack\Week 4\project_2\data\raw data\New_data_2015.csv"

happydata_2019 = pd.read_csv(path)

happydata_2015 = pd.read_csv(path3)

# %%
happydata_2019.head()
# Out:
#    Unnamed: 0      country  happiness_rank  happiness_score  gdp_per_capita  \
# 0           0      Finland               1            7.769           1.340
# 1           1      Denmark               2            7.600           1.383
# 2           2       Norway               3            7.554           1.488
# 3           3      Iceland               4            7.494           1.380
# 4           4  Netherlands               5            7.488           1.396
#
#    social_support  life_expectancy  freedom  perception_of_corruption  \
# 0           1.587            0.986    0.596                     0.393
# 1           1.573            0.996    0.592                     0.410
# 2           1.582            1.028    0.603                     0.341
# 3           1.624            1.026    0.591                     0.118
# 4           1.522            0.999    0.557                     0.298
#
#    generosity
# 0       0.153
# 1       0.252
# 2       0.271
# 3       0.354
# ...

# %%
happydata_2015.head()
# Out:
#    Unnamed: 0      country  happiness_rank  happiness_score  gdp_per_capita  \
# 0           0  Switzerland               1            7.587         1.39651
# 1           1      Iceland               2            7.561         1.30232
# 2           2      Denmark               3            7.527         1.32548
# 3           3       Norway               4            7.522         1.45900
# 4           4       Canada               5            7.427         1.32629
#
#    social_support  life_expectancy  freedom  perception_of_corruption  \
# 0         1.34951          0.94143  0.66557                   0.41978
# 1         1.40223          0.94784  0.62877                   0.14145
# 2         1.36058          0.87464  0.64938                   0.48357
# 3         1.33095          0.88521  0.66973                   0.36503
# 4         1.32261          0.90563  0.63297                   0.32957
#
#    generosity          region  standard_error  dystopia_residual
# ...

# %%
happydata_2015.columns
# Out:
# Index(['Unnamed: 0', 'country', 'happiness_rank', 'happiness_score',
#        'gdp_per_capita', 'social_support', 'life_expectancy', 'freedom',
#        'perception_of_corruption', 'generosity', 'region', 'standard_error',
#        'dystopia_residual'],
#       dtype='object')

# %%
country_df = happydata_2015[['country', 'region']].copy()

# %%
country_df.head()
# Out:
#        country          region
# 0  Switzerland  Western Europe
# 1      Iceland  Western Europe
# 2      Denmark  Western Europe
# 3       Norway  Western Europe
# 4       Canada   North America

# %%
folder_path = r"C:\Users\ShannonKnight\OneDrive - PPO Serve\Documents\ironhack\Week 4\project_2\data\raw data"

# Save the pivoted data to separate files in the specified folder
country_df.to_csv(folder_path + '\\country_region.csv')
